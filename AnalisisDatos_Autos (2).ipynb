# %% [markdown]
# <img SRC="img01.png"/>
# <center><h1 Style="color:#4682B4">Analisis de Datos</h1></center>
# <center><h5>Universidad Castro Carazo</h5></center>
# <center><h6>2C - 2022</h6></center>
# </br>
# </br>
# <p Style="text-aling: justify" >Este notebook contiene el analisis de los datos de los vehiculos a la venta por parte de la empresa Pk2, esta empresa se encuentra interesada en responder una pregunta de negocio particular.
#
# Como se puede incrementar las ventas de autos de segunda mano?
#
# Para esto se realiza un analisis del conjunto de datos facilitado por la empresa a efectos de poder brindar conocimiento sobre las ditribuciones de sus lotes de venta, los autos con mayor precio, o caracteristicas de los autos, esto para dotar de insumos suficientes a la toma de desiciones.</p>
# </br>
# </br>
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile">Fuente de datos para el analisis</a>

# %% [markdown]
# <h2 Style="color:#1E90FF">1. Carga y estandarizacion de los set de datos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Importar las librerias de necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los ecabezados de los DataFrames</li>
#     <li>Si solo Si temenos mas de 1 set de datos - Unir los set de datos en un unico Dataframe</li>
# </ol>
#
# <h3 Style="color:#2F4F4F">1.1 Importar las librerias</h3>

# %%
import pandas as pd             #se va usar para el manejo de dataFrame.
import numpy as np              #se va usar para el manejo de estructuras de datos.
import matplotlib.pyplot as ptl #para el manejo de graficos.

# %% [markdown]
# <h3 Style="color:#2F4F4F">1.2 Importar el set de datos</h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors", 
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]

df_1er_autos = pd.read_csv("autos.csv", names=cols)
df_2do_autos = pd.read_csv("Autos 1.csv", names=cols)

# %%
df_1er_autos.shape #Esto me permite conocer el tamanho del DataFrame
# Out:
# (197, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2          ?         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1          ?         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0          ?         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %%
df_1er_autos.tail(10)
# Out:
#      symboling normalized        make    fuel aspiration doors        style  \
# 187          2         94  volkswagen  diesel      turbo  four        sedan
# 188          2         94  volkswagen     gas        std  four        sedan
# 189          3          ?  volkswagen     gas        std   two  convertible
# 190          3        256  volkswagen     gas        std   two    hatchback
# 191          0          ?  volkswagen     gas        std  four        sedan
# 192          0          ?  volkswagen  diesel      turbo  four        sedan
# 193          0          ?  volkswagen     gas        std  four        wagon
# 194         -2        103       volvo     gas        std  four        sedan
# 195         -1         74       volvo     gas        std  four        wagon
# 196         -2        103       volvo     gas        std  four        sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %% [markdown]
# <h3 Style="color:#2F4F4F">1.3 Revisar encabezados de los set de datos</h3>

# %%
df_1er_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engine-size  197 non-null    int64
#  17  system       197 non-null    object
# ...

# %% [markdown]
# <h3 Style="color:#2F4F4F">1.4 Unir Archivos en un solo DataFrame</h3>

# %%
unionArchivos = [df_1er_autos, df_2do_autos] #listas de DataFrames
dfAutos = pd.concat(unionArchivos)
dfAutos.shape #El primero da la cantidad registros y el 2da la cantidad de columnas
# Out:
# (226, 26)

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
#
# [3 rows x 26 columns]

# %%
dftem = dfAutos.iloc[:, 0:3] #1er comando antes de la coma son filas y despues de la coma son columnas

# %%
dftem.head (6)
# Out:
#    symboling normalized         make
# 0          3          ?  alfa-romero
# 1          3          ?  alfa-romero
# 2          1          ?  alfa-romero
# 3          2        164         audi
# 4          2        164         audi
# 5          2          ?         audi

# %%
dftemp = dfAutos.iloc [[0,3,6,24],[0,5,6]] #1st, 4th, 7th, 25th row + 1st, 6th, 7th columns

# %%
dftemp
# Out:
#     symboling doors        style
# 0           3   two  convertible
# 3           2  four        sedan
# 6           1  four        sedan
# 24          1  four    hatchback

# %%
df_Autos = dfAutos #documento original

# %% [markdown]
# <h2 Style="color:#1E90FF">2. Valores faltantes o perdidos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Identificar como se muestran los valores faltantes (null, espacio en blanco,?)  y estandarizarlos (NaN)</li>
#     <li>Hacer un conteo de la cantidad de valores faltantes por variable (columna)</li>
#     <li>Analisis de imputacion (promedio) para los numericos </li> #para q se mantenga en los margenes
#     <li>Analisis de imputacion (el mas frecuente / ML) para caracteres</li>
#      <li>Eliminar filas o columnas con valores faltantes</li>
# </ol>
#
# <h3 Style="color:#2F4F4F">2.1 Identificar como se muestran los valores faltantesy estandarizarlos</h3>

# %%
dfAutos.replace("?", np.nan, inplace = True)
dfAutos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2        NaN         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1        NaN         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0        NaN         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %% [markdown]
# <h3 Style="color:#2F4F4F">2.2 Hacer un conteo de la cantidad de valores faltantes por variable (columna)</h3>

# %%
valoresPerdidos = dfAutos.isnull()

# %%
valoresPerdidos.head(5)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# 1   False  False  ...        False   False  False   False        False
# 2   False  False  ...        False   False  False   False        False
# 3   False  False  ...        False   False  False   False        False
# 4   False  False  ...        False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# ...

# %%
valoresPerdidos = dfAutos.isnull()
for column in valoresPerdidos.columns.values.tolist():
    print (column)
    print (valoresPerdidos[column].value_counts())
    print ("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engine-size
# False    226
# Name: engine-size, dtype: int64
#
# system
# ...

# %% [markdown]
# <h3 Style="color:#2F4F4F">2.3 Imputar Datos Numericos (columna)</h3>

# %%
avg_normalized = dfAutos["normalized"].astype(float).mean(axis=0)# 1 filas- 0 columna
print ("la media del normalized: ", avg_normalized)
# Out:
# la media del normalized:  122.28333333333333

# %%
dfAutos["normalized"].replace(np.nan, 122, inplace=True)
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
#
# [3 rows x 26 columns]

# %% [markdown]
# <h3 Style="color:#2F4F4F">2.4 Imputar Datos de tipo Caracter</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos["doors"].value_counts()
# Out:
# four    124
# two     100
# Name: doors, dtype: int64

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace=True)

# %%
valoresPerdidos = dfAutos.isnull()
for column in valoresPerdidos.columns.values.tolist():
    print (column)
    print (valoresPerdidos[column].value_counts())
    print ("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    226
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    226
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engine-size
# False    226
# Name: engine-size, dtype: int64
#
# system
# False    226
# ...

# %% [markdown]
# <h3 Style="color:#2F4F4F">2.5 Eliminar Filas con Valores faltantes</h3>

# %%
dfAutos.dropna(subset = ["price"], axis = 0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.dropna(subset = ["bore"], axis = 0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.dropna(subset = ["stroke"], axis = 0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.dropna(subset = ["horsepower"], axis = 0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos
# Out:
#      symboling normalized         make    fuel aspiration doors        style  \
# 0            3        122  alfa-romero     gas        std   two  convertible
# 1            3        122  alfa-romero     gas        std   two  convertible
# 2            1        122  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 211          0        122   volkswagen  diesel      turbo  four        sedan
# 212          0        122   volkswagen     gas        std  four        wagon
# 213         -2        103        volvo     gas        std  four        sedan
# 214         -1         74        volvo     gas        std  four        wagon
# 215         -2        103        volvo     gas        std  four        sedan
#
# ...

# %%
valoresPerdidos = dfAutos.isnull()
for column in valoresPerdidos.columns.values.tolist():
    print (column)
    print (valoresPerdidos[column].value_counts())
    print ("")
# Out:
# symboling
# False    216
# Name: symboling, dtype: int64
#
# normalized
# False    216
# Name: normalized, dtype: int64
#
# make
# False    216
# Name: make, dtype: int64
#
# fuel
# False    216
# Name: fuel, dtype: int64
#
# aspiration
# False    216
# Name: aspiration, dtype: int64
#
# doors
# False    216
# Name: doors, dtype: int64
#
# style
# False    216
# Name: style, dtype: int64
#
# wheels
# False    216
# Name: wheels, dtype: int64
#
# engine
# False    216
# Name: engine, dtype: int64
#
# base
# False    216
# Name: base, dtype: int64
#
# length
# False    216
# Name: length, dtype: int64
#
# width
# False    216
# Name: width, dtype: int64
#
# heingt
# False    216
# Name: heingt, dtype: int64
#
# curb
# False    216
# Name: curb, dtype: int64
#
# engineType
# False    216
# Name: engineType, dtype: int64
#
# Cylinders
# False    216
# Name: Cylinders, dtype: int64
#
# engine-size
# False    216
# Name: engine-size, dtype: int64
#
# system
# False    216
# ...

# %% [markdown]
# <h2 Style="color:#DAA52">3. Estandarizacion de Datos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario</li>
#     <li>Convertir los valores en funcion de su interpretacion</li>
#     <li>Normalizar los Datos para que sus valores queden entre 0 y 1</li>
#     <li>Agrupar Datos (Binning)</li>
# </ol>
#
# <h3 Style="color:#FFD700">3.1 Verificar el dominio de las variables</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
dfAutos [["normalized", "peak","horsepower"]] = dfAutos[["normalized", "peak", "horsepower"]].astype("int")
dfAutos [["bore","stroke","price"]] = dfAutos[["bore","stroke", "price"]].astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int32
# peak             int32
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h3 Style="color:#FFD700">3.2Convertir los valores en funcion de su interpretacion</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City  Higway    price
# ...

# %%
dfAutos["Ciudad-Litros/100km"]= 235/dfAutos["City"]  #Agregar columna "city" la que se toma de referencia
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  system  bore  stroke  compression horsepower  \
# 0    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0        111
# 1    rwd  front  88.6  ...    mpfi  3.47    2.68          9.0        111
# 2    rwd  front  94.5  ...    mpfi  2.68    3.47          9.0        154
# 3    fwd  front  99.8  ...    mpfi  3.19    3.40         10.0        102
# 4    4wd  front  99.4  ...    mpfi  3.19    3.40          8.0        115
#
#    peak  City Higway    price  Ciudad-Litros/100km
# ...

# %%
dfAutos["Higway-L/100km"]= 235/dfAutos["Higway"]
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway    price  Ciudad-Litros/100km  Higway-L/100km
# ...

# %% [markdown]
# <h3 Style="color:#FFD700">3.3 Normalizacion de Datos</h3>

# %%
###volver datos comparables

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            216 non-null    int64
#  1   normalized           216 non-null    int32
#  2   make                 216 non-null    object
#  3   fuel                 216 non-null    object
#  4   aspiration           216 non-null    object
#  5   doors                216 non-null    object
#  6   style                216 non-null    object
#  7   wheels               216 non-null    object
#  8   engine               216 non-null    object
#  9   base                 216 non-null    float64
#  10  length               216 non-null    float64
#  11  width                216 non-null    float64
#  12  heingt               216 non-null    float64
#  13  curb                 216 non-null    int64
#  14  engineType           216 non-null    object
# ...

# %%
dftemp = dfAutos [["length", "width", "heingt"]] #df temporal para ver los datos.
dftemp.head(5)
# Out:
#    length  width  heingt
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
dfAutos["length"] = dfAutos["length"]/dfAutos["length"].max() #hacer que los datos sean entre 0y1
dfAutos["width"] = dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingt"] = dfAutos["heingt"]/dfAutos["heingt"].max()

# %%
dftemp = dfAutos [["length", "width", "heingt"]] 
dftemp.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# <h3 Style="color:#FFD700">3.4. Binning</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway    price  Ciudad-Litros/100km  Higway-L/100km
# ...

# %%
#convertir en entero- lo hice arriba con los demas
#crear categirias

# %%
cat = np.linspace(min(dfAutos["horsepower"]), max(dfAutos["horsepower"]),4)
cat
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
nombres = ["bajo", "medio", "alto"]
dfAutos["horsepower-bins"] = pd.cut(dfAutos["horsepower"], bins = cat, labels = nombres, include_lowest=True)
dfAutos[["horsepower", "horsepower-bins"]].head(5)
# Out:
#    horsepower horsepower-bins
# 0         111            bajo
# 1         111            bajo
# 2         154           medio
# 3         102            bajo
# 4         115            bajo

# %%
dfAutos["horsepower-bins"].value_counts()
# Out:
# bajo     169
# medio     42
# alto       5
# Name: horsepower-bins, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(dfAutos["horsepower-bins"])
plt.xlabel("Horsepower")
plt.ylabel("Cantodad Autos")
plt.title("Distribucion de Autos segun caballos de fuerza")
plt.show()

# %%
dfAutos.head(10)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
# 5          2         122         audi  gas        std   two        sedan
# 6          1         158         audi  gas        std  four        sedan
# 7          1         122         audi  gas        std  four        wagon
# 8          1         158         audi  gas      turbo  four        sedan
# 9          2         192          bmw  gas        std   two        sedan
#
#   wheels engine   base  ...  stroke  compression  horsepower  peak City  \
# 0    rwd  front   88.6  ...    2.68          9.0         111  5000   21
# ...

# %% [markdown]
# <h2 Style="color:#6495ED">4. Visualizacion de Datos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Responder las preguntas de Negocio</li>
#     <li>Liberar Conocimiento</li>
#     <li>Generar Informe al Negocio</li>
# </ol>

# %%
gf1 = dfAutos.groupby(["horsepower-bins"]).count()
gf1 = gf1.iloc[:,:1]
gf1
# Out:
#                  symboling
# horsepower-bins
# bajo                   169
# medio                   42
# alto                     5

# %%
eje_x = ("Bajo","Medip","Alto")
eje_y = gf1["symboling"].tolist()

#creamos la grafica
plt.bar(eje_x, eje_y)

#Leyenda en el eje_y
plt.ylabel("Cantidad de Autos")

#leyenda en el eje_x
plt.xlabel("Caballos de Fuerza")

#titulo del grafico
plt.title("Autos Agrupados por Caballos de fuerza")

#para que no salga la leyenda de arriba
plt.show()

#tamano de grafico
plt.figure(figsize=(15,30))

# %%
gf2=dfAutos.groupby(["make"]).count()
gf2=gf2.iloc[:,:1]
#gf2.sort_values("syboling") para ordenar de menor a mayor
gf2
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 13
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                4
# saab                   6
# subaru                12
# toyota                46
# volkswagen            24
# volvo                  6

# %%
eje_x = ("alfa-romero", "audi", "bmw","chevrolet", "dodge", "honda", "isuzu", "jaguar", "mazda", "Merecedez", "Mercury",
        "mitsubishi", "nissan", "peugot", "plymounth", "porshe", "saab", "subaru", "toyota", "volkswagen", "volvo")
eje_y = gf2["symboling"].tolist()

plt.rcdefaults()
fig, ax = plt.subplots()

#Este se alimenta de la lista denominada eje_x
y_pos = np.arange(len(eje_x))

ax.barh(y_pos, eje_y, align='center', color= "#006400", alpha=0.5 )

ax.set_yticks(y_pos, labels=eje_x, color = "black")
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Cantidad de Vehiculos').set_color('#483D8B')
ax.set_title('Cantidad de Vehiculos segun fabricante')

plt.show()

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  stroke  compression  horsepower  peak City Higway  \
# 0    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
# 1    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
#
#      price Ciudad-Litros/100km  Higway-L/100km  horsepower-bins
# 0  13495.0           11.190476        8.703704             bajo
# 1  16500.0           11.190476        8.703704             bajo
#
# [2 rows x 29 columns]

# %%
gf3 = dfAutos.groupby(['doors']).count()
gf3 = gf3.iloc[:,:1]
gf3
# Out:
#        symboling
# doors
# four         124
# two           92

# %%
etiqueta = "Four", "Two" 
sizes = gf3["symboling"].tolist()

separacion = (0, 0.1)

fig1, ax1 = plt.subplots()

ax1.pie(sizes, explode=separacion, labels=etiqueta, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')

plt.show()

# %%
gf4 = df_Autos.groupby(['style']).count()
gf4 = gf4.iloc[:,:1]
gf4
# Out:
#              symboling
# style
# convertible          8
# hardtop             10
# hatchback           70
# sedan              103
# wagon               25

# %%
fig, ax = plt.subplots(figsize=(8,4), subplot_kw=dict(aspect="equal"))

data = gf4['symboling'].tolist()
estilo = ['Convertible', 'Hardtop', 'Hatchback', 'Sedan', 'Wagon']


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))
ax.legend(wedges, estilo,
          title="Estilo",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1.5))

plt.setp(autotexts, size=6, weight="bold")

ax.set_title("Autos segun estilo")

plt.show()

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  stroke  compression  horsepower  peak City Higway  \
# 0    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
# 1    rwd  front  88.6  ...    2.68          9.0         111  5000   21     27
# 2    rwd  front  94.5  ...    3.47          9.0         154  5000   19     26
# 3    fwd  front  99.8  ...    3.40         10.0         102  5500   24     30
# 4    4wd  front  99.4  ...    3.40          8.0         115  5500   18     22
#
# ...

# %%
# Colores
colors = ['#FCF4D9', '#8ED2C9', '#00AAA0', 
          '#FF7A5A', '#FFB85F']

 

# Separaciones
explode = (0.05, 0.05, 0.05, 0.05, 0.05)
  
# Creacion de grafica circular
plt.pie(data, colors=colors, labels=estilo,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)
  
# dibujo de circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
  
# Esta linea agrega el cirulo blanco sobre la grafica
fig.gca().add_artist(centre_circle)
  
plt.title('Distribucion de autos segun estilo')
  
# Displaing Chart
plt.show()

# %%
dfAutos[["price","horsepower"]].head(10)
# Out:
#      price  horsepower
# 0  13495.0         111
# 1  16500.0         111
# 2  16500.0         154
# 3  13950.0         102
# 4  17450.0         115
# 5  15250.0         110
# 6  17710.0         110
# 7  18920.0         110
# 8  23875.0         140
# 9  16430.0         101

# %%
import matplotlib.cbook as cbook


fig, ax = plt.subplots()
ax.scatter(dfAutos['price'], dfAutos['Ciudad-Litros/100km'],s=dfAutos['horsepower'], alpha=0.4)

 

ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo litros gasolina en ciudad", fontsize=15)
ax.set_title('Volume and percent change')

 

ax.grid(True)
fig.tight_layout()

 

plt.show()
